# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import random
import torch

from src.data import CymruFluencyDataset
from src.features import get_mouth_landmarks

LOAD_DIR = 'data/processed/'
SAVE_MODEL_DIR = 'registery/'
# Out:
# c:\Users\hgnis\anaconda3\Lib\site-packages\transformers\utils\generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %%
# Set seed for reproducibility
seed = 42 

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # If using multiple GPUs

#torch.backends.cudnn.deterministic = True
#torch.backends.cudnn.benchmark = False

# %%
audio_static_feat = np.load(LOAD_DIR + 'audio_static_feat.npy')
audio_dynamic_feat = np.load(LOAD_DIR + 'audio_dynamic_feat.npy')
landmarks_feat = np.load(LOAD_DIR + 'landmarks.npy')
labels = np.load(LOAD_DIR + 'labels.npy')
landmarks_mouth_feat = get_mouth_landmarks(landmarks_feat)

# %%
from src.models import AudioGRUNet, LandmarkSTGCNNet, AudioLSTM, AudioLSTMAttn, LandmarkLSTM

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import StratifiedShuffleSplit

# %%
def train_model(model, data_type, dataloaders, criterion, optimizer, num_epochs=50, device='cpu'):
    """
    Train the model and return the best model.

    Parameters:
        model: PyTorch model
        dataloaders: dict with keys 'train' and 'val' and values DataLoader objects
        criterion: loss function
        optimizer: optimization algorithm
        num_epochs: number of epochs
        device: 'cpu' or 'cuda'
    
    Returns:
        best_model: PyTorch model with best validation accuracy
    """
    best_model_wts = model.state_dict()
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f"Epoch {epoch+1}/{num_epochs}")

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # set model to training mode
            else:
                model.eval()   # set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            for audio_inputs, landmark_inputs, labels in dataloaders[phase]:
                if data_type == 'audio':
                    inputs = audio_inputs.to(device)
                elif data_type == 'landmark':
                    inputs = landmark_inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()
                
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    _, preds = torch.max(outputs, 1)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels)

            epoch_loss = running_loss / len(dataloaders[phase].sampler)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].sampler)
            print(f"{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}")

            # deep copy the model if validation accuracy improves
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = model.state_dict()

    print(f"Best Validation Accuracy: {best_acc:.4f}")
    model.load_state_dict(best_model_wts)
    return model

# %%
def main(
        dataset,
        data_type,
        labels,
        model_constructor,
        model_kwargs,
        save_path,
        num_epochs=50,
        batch_size=16,
        lr=1e-3,
):

    np.random.seed(42)
    
    n_samples = len(dataset)
    indices = np.arange(n_samples)
    
    sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
    train_idx, valid_idx = next(sss.split(indices, labels))
    
    train_dataset = Subset(dataset, train_idx)
    valid_dataset = Subset(dataset, valid_idx)
    
    dataloaders = {
        'train': DataLoader(train_dataset, batch_size=batch_size, shuffle=True),
        'val': DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
    }
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    model = model_constructor(**model_kwargs)
    model = model.to(device)
    
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    
    model = train_model(model, data_type, dataloaders, criterion, optimizer, num_epochs, device)
    
    torch.save(model.state_dict(), save_path)
    print(f"Model saved to {save_path}")

# %%
audio_lstm_kwargs = {
    'audio_input_size': 23,
    'lstm_hidden_size': 64,
    'lstm_num_layers': 1,
    'dropout': 0.8,
    'num_classes': 2
}

dataset = CymruFluencyDataset(audio_dynamic_feat, landmarks_mouth_feat, labels)

main(
    dataset=dataset,
    data_type='audio',
    labels=labels,
    model_constructor=AudioLSTM,
    model_kwargs=audio_lstm_kwargs,
    save_path=SAVE_MODEL_DIR + 'audio_lstm.pth',
    num_epochs=50,
    batch_size=16,
    lr=1e-3
)
# Out:
# Epoch 1/50
# Train Loss: 0.6996 Acc: 0.5351
# Val Loss: 0.6939 Acc: 0.5253
# Epoch 2/50
# Train Loss: 0.6932 Acc: 0.5307
# Val Loss: 0.6841 Acc: 0.4949
# Epoch 3/50
# Train Loss: 0.6523 Acc: 0.6491
# Val Loss: 0.6764 Acc: 0.5253
# Epoch 4/50
# Train Loss: 0.6750 Acc: 0.5789
# Val Loss: 0.6637 Acc: 0.6162
# Epoch 5/50
# Train Loss: 0.6751 Acc: 0.6009
# Val Loss: 0.6569 Acc: 0.6364
# Epoch 6/50
# Train Loss: 0.6460 Acc: 0.6447
# Val Loss: 0.6513 Acc: 0.6364
# Epoch 7/50
# Train Loss: 0.6228 Acc: 0.6711
# Val Loss: 0.6440 Acc: 0.6162
# Epoch 8/50
# Train Loss: 0.6384 Acc: 0.6009
# Val Loss: 0.6281 Acc: 0.6768
# Epoch 9/50
# Train Loss: 0.6347 Acc: 0.6623
# Val Loss: 0.6180 Acc: 0.6869
# Epoch 10/50
# Train Loss: 0.6002 Acc: 0.6667
# Val Loss: 0.6068 Acc: 0.7071
# Epoch 11/50
# Train Loss: 0.5961 Acc: 0.7018
# Val Loss: 0.6025 Acc: 0.6869
# Epoch 12/50
# Train Loss: 0.5594 Acc: 0.7281
# Val Loss: 0.5870 Acc: 0.6869
# Epoch 13/50
# Train Loss: 0.5586 Acc: 0.6974
# Val Loss: 0.5727 Acc: 0.7071
# Epoch 14/50
# Train Loss: 0.5525 Acc: 0.7281
# Val Loss: 0.5629 Acc: 0.7778
# Epoch 15/50
# Train Loss: 0.5731 Acc: 0.7149
# Val Loss: 0.5613 Acc: 0.7475
# Epoch 16/50
# Train Loss: 0.5128 Acc: 0.7851
# Val Loss: 0.5486 Acc: 0.7374
# Epoch 17/50
# Train Loss: 0.5346 Acc: 0.7105
# Val Loss: 0.5234 Acc: 0.7677
# Epoch 18/50
# Train Loss: 0.5087 Acc: 0.7632
# Val Loss: 0.5120 Acc: 0.7576
# Epoch 19/50
# Train Loss: 0.4914 Acc: 0.7895
# Val Loss: 0.4984 Acc: 0.7879
# Epoch 20/50
# Train Loss: 0.4658 Acc: 0.7982
# Val Loss: 0.5003 Acc: 0.7778
# Epoch 21/50
# Train Loss: 0.4422 Acc: 0.8070
# Val Loss: 0.4803 Acc: 0.7980
# Epoch 22/50
# Train Loss: 0.4340 Acc: 0.7982
# Val Loss: 0.4718 Acc: 0.8081
# Epoch 23/50
# Train Loss: 0.4094 Acc: 0.8246
# Val Loss: 0.4476 Acc: 0.8081
# Epoch 24/50
# Train Loss: 0.4269 Acc: 0.7675
# Val Loss: 0.4726 Acc: 0.7778
# Epoch 25/50
# Train Loss: 0.4168 Acc: 0.8246
# Val Loss: 0.4484 Acc: 0.8283
# Epoch 26/50
# Train Loss: 0.3951 Acc: 0.8246
# Val Loss: 0.4573 Acc: 0.8586
# Epoch 27/50
# Train Loss: 0.3387 Acc: 0.8596
# Val Loss: 0.4372 Acc: 0.7980
# Epoch 28/50
# Train Loss: 0.3451 Acc: 0.8596
# Val Loss: 0.4408 Acc: 0.8182
# Epoch 29/50
# Train Loss: 0.3300 Acc: 0.8289
# Val Loss: 0.4003 Acc: 0.8788
# Epoch 30/50
# Train Loss: 0.2781 Acc: 0.9123
# Val Loss: 0.4328 Acc: 0.8283
# Epoch 31/50
# Train Loss: 0.2874 Acc: 0.8728
# Val Loss: 0.3943 Acc: 0.8384
# Epoch 32/50
# Train Loss: 0.2454 Acc: 0.9079
# Val Loss: 0.4140 Acc: 0.8283
# Epoch 33/50
# Train Loss: 0.2850 Acc: 0.8596
# Val Loss: 0.4015 Acc: 0.8586
# Epoch 34/50
# Train Loss: 0.2469 Acc: 0.9079
# Val Loss: 0.4219 Acc: 0.8586
# Epoch 35/50
# Train Loss: 0.2259 Acc: 0.9254
# Val Loss: 0.3937 Acc: 0.8485
# Epoch 36/50
# Train Loss: 0.2227 Acc: 0.8991
# Val Loss: 0.4119 Acc: 0.8586
# Epoch 37/50
# Train Loss: 0.1953 Acc: 0.9167
# Val Loss: 0.3802 Acc: 0.8687
# Epoch 38/50
# Train Loss: 0.1786 Acc: 0.9386
# Val Loss: 0.4118 Acc: 0.8889
# Epoch 39/50
# Train Loss: 0.1717 Acc: 0.9474
# Val Loss: 0.4217 Acc: 0.8485
# Epoch 40/50
# Train Loss: 0.1932 Acc: 0.8991
# Val Loss: 0.4167 Acc: 0.8687
# Epoch 41/50
# Train Loss: 0.1661 Acc: 0.9298
# Val Loss: 0.4170 Acc: 0.8687
# Epoch 42/50
# Train Loss: 0.1464 Acc: 0.9561
# Val Loss: 0.4211 Acc: 0.8586
# Epoch 43/50
# Train Loss: 0.1493 Acc: 0.9430
# Val Loss: 0.4438 Acc: 0.8485
# Epoch 44/50
# Train Loss: 0.1402 Acc: 0.9561
# Val Loss: 0.5394 Acc: 0.8081
# Epoch 45/50
# Train Loss: 0.1221 Acc: 0.9693
# Val Loss: 0.4415 Acc: 0.8990
# Epoch 46/50
# Train Loss: 0.1331 Acc: 0.9605
# Val Loss: 0.4440 Acc: 0.8788
# Epoch 47/50
# Train Loss: 0.1149 Acc: 0.9737
# Val Loss: 0.4662 Acc: 0.8889
# Epoch 48/50
# Train Loss: 0.1059 Acc: 0.9561
# Val Loss: 0.4244 Acc: 0.8384
# Epoch 49/50
# Train Loss: 0.1292 Acc: 0.9649
# Val Loss: 0.4978 Acc: 0.8687
# Epoch 50/50
# Train Loss: 0.0905 Acc: 0.9737
# Val Loss: 0.4909 Acc: 0.8384
# Best Validation Accuracy: 0.8990
# Model saved to registery/audio_lstm.pth

# %%
audio_lstmatt_kwargs = {
    'audio_input_size': 23,
    'lstm_hidden_size': 16,
    'lstm_num_layers': 1,
    'dropout': 0.8,
    'num_classes': 2,
    'num_heads': 1
}

dataset = CymruFluencyDataset(audio_dynamic_feat, landmarks_mouth_feat, labels)

main(
    dataset,
    'audio',
    labels,
    AudioLSTMAttn,
    audio_lstmatt_kwargs,
    SAVE_MODEL_DIR + 'audio_lstmatt.pth',
    num_epochs=50,
    batch_size=16,
    lr=1e-3
)
# Out:
# Epoch 1/50
# Train Loss: 0.7008 Acc: 0.4605
# Val Loss: 0.6942 Acc: 0.4747
# Epoch 2/50
# Train Loss: 0.6855 Acc: 0.5921
# Val Loss: 0.6923 Acc: 0.5657
# Epoch 3/50
# Train Loss: 0.6930 Acc: 0.4956
# Val Loss: 0.6907 Acc: 0.5758
# Epoch 4/50
# Train Loss: 0.6818 Acc: 0.5746
# Val Loss: 0.6878 Acc: 0.5556
# Epoch 5/50
# Train Loss: 0.6793 Acc: 0.5921
# Val Loss: 0.6841 Acc: 0.5354
# Epoch 6/50
# Train Loss: 0.6737 Acc: 0.5658
# Val Loss: 0.6793 Acc: 0.5455
# Epoch 7/50
# Train Loss: 0.6740 Acc: 0.6140
# Val Loss: 0.6736 Acc: 0.6061
# Epoch 8/50
# Train Loss: 0.6563 Acc: 0.6316
# Val Loss: 0.6628 Acc: 0.5758
# Epoch 9/50
# Train Loss: 0.6380 Acc: 0.6096
# Val Loss: 0.6468 Acc: 0.6061
# Epoch 10/50
# Train Loss: 0.6348 Acc: 0.6842
# Val Loss: 0.6315 Acc: 0.6970
# Epoch 11/50
# Train Loss: 0.6062 Acc: 0.6974
# Val Loss: 0.6117 Acc: 0.6263
# Epoch 12/50
# Train Loss: 0.5716 Acc: 0.7237
# Val Loss: 0.5819 Acc: 0.7273
# Epoch 13/50
# Train Loss: 0.5248 Acc: 0.7719
# Val Loss: 0.5642 Acc: 0.7273
# Epoch 14/50
# Train Loss: 0.4992 Acc: 0.7895
# Val Loss: 0.5299 Acc: 0.7475
# Epoch 15/50
# Train Loss: 0.4795 Acc: 0.7982
# Val Loss: 0.5036 Acc: 0.7475
# Epoch 16/50
# Train Loss: 0.4363 Acc: 0.8026
# Val Loss: 0.4829 Acc: 0.7677
# Epoch 17/50
# Train Loss: 0.4033 Acc: 0.8377
# Val Loss: 0.4626 Acc: 0.7879
# Epoch 18/50
# Train Loss: 0.3853 Acc: 0.8509
# Val Loss: 0.4396 Acc: 0.8081
# Epoch 19/50
# Train Loss: 0.3729 Acc: 0.8596
# Val Loss: 0.4409 Acc: 0.7879
# Epoch 20/50
# Train Loss: 0.3100 Acc: 0.8991
# Val Loss: 0.4327 Acc: 0.7778
# Epoch 21/50
# Train Loss: 0.3011 Acc: 0.9123
# Val Loss: 0.3889 Acc: 0.7879
# Epoch 22/50
# Train Loss: 0.2603 Acc: 0.8904
# Val Loss: 0.3929 Acc: 0.7879
# Epoch 23/50
# Train Loss: 0.2780 Acc: 0.8772
# Val Loss: 0.3580 Acc: 0.8485
# Epoch 24/50
# Train Loss: 0.2536 Acc: 0.9167
# Val Loss: 0.3748 Acc: 0.8485
# Epoch 25/50
# Train Loss: 0.2141 Acc: 0.9386
# Val Loss: 0.3594 Acc: 0.8283
# Epoch 26/50
# Train Loss: 0.1869 Acc: 0.9386
# Val Loss: 0.3652 Acc: 0.8283
# Epoch 27/50
# Train Loss: 0.1579 Acc: 0.9649
# Val Loss: 0.3495 Acc: 0.8687
# Epoch 28/50
# Train Loss: 0.1585 Acc: 0.9518
# Val Loss: 0.3700 Acc: 0.8485
# Epoch 29/50
# Train Loss: 0.1410 Acc: 0.9430
# Val Loss: 0.3937 Acc: 0.8586
# Epoch 30/50
# Train Loss: 0.1364 Acc: 0.9518
# Val Loss: 0.3642 Acc: 0.8586
# Epoch 31/50
# Train Loss: 0.1241 Acc: 0.9781
# Val Loss: 0.3505 Acc: 0.8990
# Epoch 32/50
# Train Loss: 0.0919 Acc: 0.9825
# Val Loss: 0.3486 Acc: 0.8687
# Epoch 33/50
# Train Loss: 0.1031 Acc: 0.9649
# Val Loss: 0.3738 Acc: 0.8687
# Epoch 34/50
# Train Loss: 0.1071 Acc: 0.9649
# Val Loss: 0.3727 Acc: 0.8586
# Epoch 35/50
# Train Loss: 0.0839 Acc: 0.9781
# Val Loss: 0.4050 Acc: 0.8687
# Epoch 36/50
# Train Loss: 0.0868 Acc: 0.9737
# Val Loss: 0.4088 Acc: 0.8586
# Epoch 37/50
# Train Loss: 0.0748 Acc: 0.9781
# Val Loss: 0.3829 Acc: 0.8485
# Epoch 38/50
# Train Loss: 0.0720 Acc: 0.9868
# Val Loss: 0.3947 Acc: 0.8788
# Epoch 39/50
# Train Loss: 0.0772 Acc: 0.9693
# Val Loss: 0.3919 Acc: 0.8485
# Epoch 40/50
# Train Loss: 0.0572 Acc: 0.9825
# Val Loss: 0.4251 Acc: 0.8687
# Epoch 41/50
# Train Loss: 0.0579 Acc: 0.9825
# Val Loss: 0.4627 Acc: 0.8586
# Epoch 42/50
# Train Loss: 0.0356 Acc: 0.9956
# Val Loss: 0.4617 Acc: 0.8586
# Epoch 43/50
# Train Loss: 0.0433 Acc: 0.9912
# Val Loss: 0.4656 Acc: 0.8687
# Epoch 44/50
# Train Loss: 0.0400 Acc: 0.9825
# Val Loss: 0.4755 Acc: 0.8788
# Epoch 45/50
# Train Loss: 0.0413 Acc: 0.9868
# Val Loss: 0.5726 Acc: 0.8687
# Epoch 46/50
# Train Loss: 0.0464 Acc: 0.9737
# Val Loss: 0.5406 Acc: 0.8687
# Epoch 47/50
# Train Loss: 0.0758 Acc: 0.9825
# Val Loss: 0.5530 Acc: 0.8586
# Epoch 48/50
# Train Loss: 0.0740 Acc: 0.9737
# Val Loss: 0.4368 Acc: 0.8687
# Epoch 49/50
# Train Loss: 0.0465 Acc: 0.9868
# Val Loss: 0.6076 Acc: 0.8586
# Epoch 50/50
# Train Loss: 0.0502 Acc: 0.9825
# Val Loss: 0.5525 Acc: 0.8586
# Best Validation Accuracy: 0.8990
# Model saved to registery/audio_lstmatt.pth

# %%
audio_gru_kwargs = {
    'input_size': 23,
    'hidden_size': 128,
    'num_layers': 2,
    'num_classes': 2,
    'bidirectional': False,
    'gru_dropout': 0.2,
    'classifier_dropout': 0.2,
    'num_heads': 2,
}

dataset = CymruFluencyDataset(audio_dynamic_feat, landmarks_mouth_feat, labels)

main(
    dataset,
    'audio',
    labels,
    AudioGRUNet,
    audio_gru_kwargs,
    SAVE_MODEL_DIR + 'audio_gru.pth',
    num_epochs=50,
    batch_size=16,
    lr=1e-3
)
# Out:
# Epoch 1/50
# Train Loss: 0.7157 Acc: 0.5088
# Val Loss: 0.6606 Acc: 0.6465
# Epoch 2/50
# Train Loss: 0.6458 Acc: 0.6404
# Val Loss: 0.6075 Acc: 0.7172
# Epoch 3/50
# Train Loss: 0.5169 Acc: 0.7149
# Val Loss: 0.5865 Acc: 0.7172
# Epoch 4/50
# Train Loss: 0.4048 Acc: 0.8114
# Val Loss: 0.5858 Acc: 0.7374
# Epoch 5/50
# Train Loss: 0.3131 Acc: 0.8640
# Val Loss: 0.4050 Acc: 0.8081
# Epoch 6/50
# Train Loss: 0.2214 Acc: 0.9342
# Val Loss: 0.4212 Acc: 0.8485
# Epoch 7/50
# Train Loss: 0.1330 Acc: 0.9518
# Val Loss: 0.5528 Acc: 0.8384
# Epoch 8/50
# Train Loss: 0.0924 Acc: 0.9649
# Val Loss: 1.1591 Acc: 0.7980
# Epoch 9/50
# Train Loss: 0.3071 Acc: 0.9123
# Val Loss: 1.1880 Acc: 0.6869
# Epoch 10/50
# Train Loss: 0.4405 Acc: 0.7982
# Val Loss: 0.4507 Acc: 0.7980
# Epoch 11/50
# Train Loss: 0.1939 Acc: 0.9474
# Val Loss: 0.4400 Acc: 0.8384
# Epoch 12/50
# Train Loss: 0.0615 Acc: 0.9781
# Val Loss: 0.5105 Acc: 0.8485
# Epoch 13/50
# Train Loss: 0.0372 Acc: 0.9868
# Val Loss: 0.6778 Acc: 0.8586
# Epoch 14/50
# Train Loss: 0.0420 Acc: 0.9737
# Val Loss: 0.7179 Acc: 0.8485
# Epoch 15/50
# Train Loss: 0.0309 Acc: 0.9693
# Val Loss: 0.8054 Acc: 0.8586
# Epoch 16/50
# Train Loss: 0.0303 Acc: 0.9693
# Val Loss: 0.8185 Acc: 0.8586
# Epoch 17/50
# Train Loss: 0.0403 Acc: 0.9737
# Val Loss: 0.8567 Acc: 0.8586
# Epoch 18/50
# Train Loss: 0.0284 Acc: 0.9868
# Val Loss: 0.8786 Acc: 0.8687
# Epoch 19/50
# Train Loss: 0.0160 Acc: 0.9868
# Val Loss: 0.9274 Acc: 0.8586
# Epoch 20/50
# Train Loss: 0.0244 Acc: 0.9868
# Val Loss: 0.9720 Acc: 0.8586
# Epoch 21/50
# Train Loss: 0.0428 Acc: 0.9737
# Val Loss: 0.9874 Acc: 0.8586
# Epoch 22/50
# Train Loss: 0.0366 Acc: 0.9781
# Val Loss: 0.9997 Acc: 0.8586
# Epoch 23/50
# Train Loss: 0.0216 Acc: 0.9868
# Val Loss: 1.0421 Acc: 0.8586
# Epoch 24/50
# Train Loss: 0.0314 Acc: 0.9737
# Val Loss: 1.0614 Acc: 0.8586
# Epoch 25/50
# Train Loss: 0.0305 Acc: 0.9825
# Val Loss: 1.0533 Acc: 0.8687
# Epoch 26/50
# Train Loss: 0.0429 Acc: 0.9693
# Val Loss: 1.0470 Acc: 0.8687
# Epoch 27/50
# Train Loss: 0.0219 Acc: 0.9825
# Val Loss: 1.0907 Acc: 0.8687
# Epoch 28/50
# Train Loss: 0.0342 Acc: 0.9693
# Val Loss: 1.1148 Acc: 0.8687
# Epoch 29/50
# Train Loss: 0.0331 Acc: 0.9825
# Val Loss: 1.1214 Acc: 0.8687
# Epoch 30/50
# Train Loss: 0.0386 Acc: 0.9868
# Val Loss: 1.1684 Acc: 0.8586
# Epoch 31/50
# Train Loss: 0.0184 Acc: 0.9868
# Val Loss: 1.1992 Acc: 0.8586
# Epoch 32/50
# Train Loss: 0.0362 Acc: 0.9781
# Val Loss: 1.2055 Acc: 0.8586
# Epoch 33/50
# Train Loss: 0.0335 Acc: 0.9781
# Val Loss: 1.2025 Acc: 0.8586
# Epoch 34/50
# Train Loss: 0.0211 Acc: 0.9868
# Val Loss: 1.2052 Acc: 0.8687
# Epoch 35/50
# Train Loss: 0.0272 Acc: 0.9825
# Val Loss: 1.2273 Acc: 0.8485
# Epoch 36/50
# Train Loss: 0.0292 Acc: 0.9868
# Val Loss: 1.2366 Acc: 0.8586
# Epoch 37/50
# Train Loss: 0.0395 Acc: 0.9737
# Val Loss: 1.2328 Acc: 0.8687
# Epoch 38/50
# Train Loss: 0.0308 Acc: 0.9781
# Val Loss: 1.2306 Acc: 0.8687
# Epoch 39/50
# Train Loss: 0.0323 Acc: 0.9693
# Val Loss: 1.2378 Acc: 0.8687
# Epoch 40/50
# Train Loss: 0.0354 Acc: 0.9649
# Val Loss: 1.2497 Acc: 0.8687
# Epoch 41/50
# Train Loss: 0.0179 Acc: 0.9912
# Val Loss: 1.2645 Acc: 0.8687
# Epoch 42/50
# Train Loss: 0.0118 Acc: 0.9956
# Val Loss: 1.2972 Acc: 0.8687
# Epoch 43/50
# Train Loss: 0.0323 Acc: 0.9649
# Val Loss: 1.2971 Acc: 0.8687
# Epoch 44/50
# Train Loss: 0.0277 Acc: 0.9781
# Val Loss: 1.3116 Acc: 0.8586
# Epoch 45/50
# Train Loss: 0.0273 Acc: 0.9825
# Val Loss: 1.3182 Acc: 0.8586
# Epoch 46/50
# Train Loss: 0.0094 Acc: 0.9912
# Val Loss: 1.3329 Acc: 0.8586
# Epoch 47/50
# Train Loss: 0.0248 Acc: 0.9781
# Val Loss: 1.3408 Acc: 0.8586
# Epoch 48/50
# Train Loss: 0.0243 Acc: 0.9868
# Val Loss: 1.3456 Acc: 0.8586
# Epoch 49/50
# Train Loss: 0.0302 Acc: 0.9825
# Val Loss: 1.3517 Acc: 0.8586
# Epoch 50/50
# Train Loss: 0.0550 Acc: 0.9605
# Val Loss: 1.3561 Acc: 0.8687
# Best Validation Accuracy: 0.8687
# Model saved to registery/audio_gru.pth

# %%
landmark_stgcn_kwargs = {
    "num_nodes": 20, 
    "in_channels": 3, 
    "hidden_channels": [64, 128], 
    "stgcn_dropout": 0.2, 
    "num_heads": 4, 
    "classifier_dropout": 0.2,
    "num_classes": 2
}

dataset = CymruFluencyDataset(audio_dynamic_feat, landmarks_mouth_feat, labels)

main(dataset, 'landmark', labels, LandmarkSTGCNNet, landmark_stgcn_kwargs, SAVE_MODEL_DIR + 'landmark_stgcn.pth')
# Out:
# Epoch 1/50
# Train Loss: 0.6642 Acc: 0.5833
# Val Loss: 0.7144 Acc: 0.5253
# Epoch 2/50
# Train Loss: 0.5921 Acc: 0.7105
# Val Loss: 0.6442 Acc: 0.6465
# Epoch 3/50
# Train Loss: 0.6141 Acc: 0.6798
# Val Loss: 0.6350 Acc: 0.6465
# Epoch 4/50
# Train Loss: 0.5794 Acc: 0.7105
# Val Loss: 0.5877 Acc: 0.6667
# Epoch 5/50
# Train Loss: 0.5331 Acc: 0.7105
# Val Loss: 0.5042 Acc: 0.7374
# Epoch 6/50
# Train Loss: 0.5484 Acc: 0.7105
# Val Loss: 0.5122 Acc: 0.6970
# Epoch 7/50
# Train Loss: 0.5339 Acc: 0.6798
# Val Loss: 0.4878 Acc: 0.7172
# Epoch 8/50
# Train Loss: 0.5208 Acc: 0.7325
# Val Loss: 0.4982 Acc: 0.7071
# Epoch 9/50
# Train Loss: 0.5526 Acc: 0.6974
# Val Loss: 0.5366 Acc: 0.7071
# Epoch 10/50
# Train Loss: 0.6092 Acc: 0.6842
# Val Loss: 0.5028 Acc: 0.7475
# Epoch 11/50
# Train Loss: 0.5267 Acc: 0.7237
# Val Loss: 0.5293 Acc: 0.6869
# Epoch 12/50
# Train Loss: 0.5104 Acc: 0.7325
# Val Loss: 0.5027 Acc: 0.7374
# Epoch 13/50
# Train Loss: 0.5451 Acc: 0.7018
# Val Loss: 0.5033 Acc: 0.7374
# Epoch 14/50
# Train Loss: 0.5637 Acc: 0.7281
# Val Loss: 0.5524 Acc: 0.7273
# Epoch 15/50
# Train Loss: 0.5826 Acc: 0.7061
# Val Loss: 0.5506 Acc: 0.7071
# Epoch 16/50
# Train Loss: 0.5392 Acc: 0.6886
# Val Loss: 0.4876 Acc: 0.7374
# Epoch 17/50
# Train Loss: 0.4651 Acc: 0.7500
# Val Loss: 0.5114 Acc: 0.7374
# Epoch 18/50
# Train Loss: 0.4906 Acc: 0.7368
# Val Loss: 0.5070 Acc: 0.7172
# Epoch 19/50
# Train Loss: 0.5100 Acc: 0.7325
# Val Loss: 0.5474 Acc: 0.7576
# Epoch 20/50
# Train Loss: 0.4872 Acc: 0.7325
# Val Loss: 0.5474 Acc: 0.7071
# Epoch 21/50
# Train Loss: 0.4642 Acc: 0.7675
# Val Loss: 0.4450 Acc: 0.7677
# Epoch 22/50
# Train Loss: 0.4740 Acc: 0.7325
# Val Loss: 0.4927 Acc: 0.7273
# Epoch 23/50
# Train Loss: 0.4649 Acc: 0.7895
# Val Loss: 0.4921 Acc: 0.7475
# Epoch 24/50
# Train Loss: 0.4521 Acc: 0.7500
# Val Loss: 0.4524 Acc: 0.7677
# Epoch 25/50
# Train Loss: 0.5168 Acc: 0.7281
# Val Loss: 0.4628 Acc: 0.7172
# Epoch 26/50
# Train Loss: 0.5088 Acc: 0.7500
# Val Loss: 0.5072 Acc: 0.7374
# Epoch 27/50
# Train Loss: 0.4679 Acc: 0.7675
# Val Loss: 0.4590 Acc: 0.7273
# Epoch 28/50
# Train Loss: 0.4593 Acc: 0.7895
# Val Loss: 0.4727 Acc: 0.7677
# Epoch 29/50
# Train Loss: 0.4863 Acc: 0.7412
# Val Loss: 0.4591 Acc: 0.7475
# Epoch 30/50
# Train Loss: 0.4522 Acc: 0.7939
# Val Loss: 0.5338 Acc: 0.7273
# Epoch 31/50
# Train Loss: 0.4655 Acc: 0.8070
# Val Loss: 0.4520 Acc: 0.7475
# Epoch 32/50
# Train Loss: 0.4776 Acc: 0.7632
# Val Loss: 0.4631 Acc: 0.7475
# Epoch 33/50
# Train Loss: 0.4548 Acc: 0.8070
# Val Loss: 0.4933 Acc: 0.7374
# Epoch 34/50
# Train Loss: 0.4800 Acc: 0.7588
# Val Loss: 0.4740 Acc: 0.6970
# Epoch 35/50
# Train Loss: 0.4551 Acc: 0.7939
# Val Loss: 0.4690 Acc: 0.7374
# Epoch 36/50
# Train Loss: 0.4220 Acc: 0.8026
# Val Loss: 0.4548 Acc: 0.7374
# Epoch 37/50
# Train Loss: 0.4677 Acc: 0.7939
# Val Loss: 0.4549 Acc: 0.7576
# Epoch 38/50
# Train Loss: 0.4542 Acc: 0.7719
# Val Loss: 0.4586 Acc: 0.7475
# Epoch 39/50
# Train Loss: 0.4161 Acc: 0.8114
# Val Loss: 0.4332 Acc: 0.7374
# Epoch 40/50
# Train Loss: 0.4387 Acc: 0.7851
# Val Loss: 0.4579 Acc: 0.7778
# Epoch 41/50
# Train Loss: 0.4838 Acc: 0.7851
# Val Loss: 0.4367 Acc: 0.7475
# Epoch 42/50
# Train Loss: 0.4678 Acc: 0.7544
# Val Loss: 0.4460 Acc: 0.7576
# Epoch 43/50
# Train Loss: 0.4634 Acc: 0.7895
# Val Loss: 0.4403 Acc: 0.7778
# Epoch 44/50
# Train Loss: 0.4453 Acc: 0.7588
# Val Loss: 0.4242 Acc: 0.7576
# Epoch 45/50
# Train Loss: 0.3910 Acc: 0.8377
# Val Loss: 0.4061 Acc: 0.7576
# Epoch 46/50
# Train Loss: 0.4705 Acc: 0.7412
# Val Loss: 0.4534 Acc: 0.7576
# Epoch 47/50
# Train Loss: 0.4788 Acc: 0.7851
# Val Loss: 0.4207 Acc: 0.7879
# Epoch 48/50
# Train Loss: 0.4441 Acc: 0.7675
# Val Loss: 0.4277 Acc: 0.7677
# Epoch 49/50
# Train Loss: 0.3829 Acc: 0.8289
# Val Loss: 0.4106 Acc: 0.7677
# Epoch 50/50
# Train Loss: 0.3962 Acc: 0.8158
# Val Loss: 0.4137 Acc: 0.7677
# Best Validation Accuracy: 0.7879
# Model saved to registery/landmark_stgcn.pth

# %%
landmark_stgcn_kwargs = {
    "landmark_input_size": 60, 
    "lstm_hidden_size": 128, 
    "lstm_num_layers": 2,
    "dropout": 0.2,
    "num_classes": 2
}

dataset = CymruFluencyDataset(audio_dynamic_feat, landmarks_mouth_feat, labels)

main(
    dataset,
    'landmark',
    labels,
    LandmarkLSTM,
    landmark_stgcn_kwargs,
    SAVE_MODEL_DIR + 'landmark_lstm.pth',
    lr=5e-5
)
# Out:
# Epoch 1/50
# Train Loss: 0.6929 Acc: 0.5395
# Val Loss: 0.6873 Acc: 0.5758
# Epoch 2/50
# Train Loss: 0.6852 Acc: 0.5921
# Val Loss: 0.6826 Acc: 0.6364
# Epoch 3/50
# Train Loss: 0.6803 Acc: 0.6184
# Val Loss: 0.6783 Acc: 0.6364
# Epoch 4/50
# Train Loss: 0.6747 Acc: 0.6360
# Val Loss: 0.6727 Acc: 0.6364
# Epoch 5/50
# Train Loss: 0.6697 Acc: 0.6535
# Val Loss: 0.6671 Acc: 0.6263
# Epoch 6/50
# Train Loss: 0.6640 Acc: 0.6535
# Val Loss: 0.6609 Acc: 0.6061
# Epoch 7/50
# Train Loss: 0.6538 Acc: 0.6711
# Val Loss: 0.6518 Acc: 0.6162
# Epoch 8/50
# Train Loss: 0.6459 Acc: 0.6711
# Val Loss: 0.6425 Acc: 0.6566
# Epoch 9/50
# Train Loss: 0.6342 Acc: 0.6754
# Val Loss: 0.6336 Acc: 0.6465
# Epoch 10/50
# Train Loss: 0.6249 Acc: 0.6754
# Val Loss: 0.6237 Acc: 0.6566
# Epoch 11/50
# Train Loss: 0.6117 Acc: 0.6754
# Val Loss: 0.6119 Acc: 0.6364
# Epoch 12/50
# Train Loss: 0.5985 Acc: 0.6886
# Val Loss: 0.5971 Acc: 0.6566
# Epoch 13/50
# Train Loss: 0.5785 Acc: 0.6886
# Val Loss: 0.5814 Acc: 0.6465
# Epoch 14/50
# Train Loss: 0.5566 Acc: 0.6930
# Val Loss: 0.5543 Acc: 0.6566
# Epoch 15/50
# Train Loss: 0.5205 Acc: 0.7281
# Val Loss: 0.5033 Acc: 0.7374
# Epoch 16/50
# Train Loss: 0.4684 Acc: 0.8289
# Val Loss: 0.4389 Acc: 0.8788
# Epoch 17/50
# Train Loss: 0.4108 Acc: 0.8816
# Val Loss: 0.3860 Acc: 0.8687
# Epoch 18/50
# Train Loss: 0.3746 Acc: 0.8904
# Val Loss: 0.3584 Acc: 0.8788
# Epoch 19/50
# Train Loss: 0.3637 Acc: 0.8860
# Val Loss: 0.3673 Acc: 0.8687
# Epoch 20/50
# Train Loss: 0.3527 Acc: 0.8772
# Val Loss: 0.4383 Acc: 0.8182
# Epoch 21/50
# Train Loss: 0.3598 Acc: 0.8816
# Val Loss: 0.3586 Acc: 0.8687
# Epoch 22/50
# Train Loss: 0.3041 Acc: 0.9167
# Val Loss: 0.3023 Acc: 0.8990
# Epoch 23/50
# Train Loss: 0.2665 Acc: 0.9474
# Val Loss: 0.3211 Acc: 0.8788
# Epoch 24/50
# Train Loss: 0.2521 Acc: 0.9430
# Val Loss: 0.3171 Acc: 0.8586
# Epoch 25/50
# Train Loss: 0.2342 Acc: 0.9518
# Val Loss: 0.3150 Acc: 0.8788
# Epoch 26/50
# Train Loss: 0.1863 Acc: 0.9737
# Val Loss: 0.2708 Acc: 0.9091
# Epoch 27/50
# Train Loss: 0.2640 Acc: 0.9123
# Val Loss: 0.3219 Acc: 0.8788
# Epoch 28/50
# Train Loss: 0.4935 Acc: 0.8114
# Val Loss: 0.5025 Acc: 0.7980
# Epoch 29/50
# Train Loss: 0.4492 Acc: 0.8289
# Val Loss: 0.4175 Acc: 0.8283
# Epoch 30/50
# Train Loss: 0.3265 Acc: 0.8772
# Val Loss: 0.3693 Acc: 0.8384
# Epoch 31/50
# Train Loss: 0.3003 Acc: 0.9035
# Val Loss: 0.2866 Acc: 0.8990
# Epoch 32/50
# Train Loss: 0.2406 Acc: 0.9342
# Val Loss: 0.2665 Acc: 0.9192
# Epoch 33/50
# Train Loss: 0.2232 Acc: 0.9430
# Val Loss: 0.2642 Acc: 0.9091
# Epoch 34/50
# Train Loss: 0.2213 Acc: 0.9386
# Val Loss: 0.2424 Acc: 0.9293
# Epoch 35/50
# Train Loss: 0.2044 Acc: 0.9474
# Val Loss: 0.2829 Acc: 0.8788
# Epoch 36/50
# Train Loss: 0.2161 Acc: 0.9342
# Val Loss: 0.2478 Acc: 0.9192
# Epoch 37/50
# Train Loss: 0.4424 Acc: 0.8640
# Val Loss: 0.7718 Acc: 0.6768
# Epoch 38/50
# Train Loss: 0.6440 Acc: 0.7368
# Val Loss: 0.5777 Acc: 0.7677
# Epoch 39/50
# Train Loss: 0.6284 Acc: 0.7237
# Val Loss: 0.5564 Acc: 0.7475
# Epoch 40/50
# Train Loss: 0.4575 Acc: 0.8114
# Val Loss: 0.4091 Acc: 0.8384
# Epoch 41/50
# Train Loss: 0.3353 Acc: 0.8772
# Val Loss: 0.3243 Acc: 0.8889
# Epoch 42/50
# Train Loss: 0.2735 Acc: 0.9254
# Val Loss: 0.3378 Acc: 0.8788
# Epoch 43/50
# Train Loss: 0.2533 Acc: 0.9342
# Val Loss: 0.3368 Acc: 0.8687
# Epoch 44/50
# Train Loss: 0.2688 Acc: 0.9167
# Val Loss: 0.3818 Acc: 0.8485
# Epoch 45/50
# Train Loss: 0.2582 Acc: 0.9211
# Val Loss: 0.3271 Acc: 0.8788
# Epoch 46/50
# Train Loss: 0.2487 Acc: 0.9167
# Val Loss: 0.3036 Acc: 0.8788
# Epoch 47/50
# Train Loss: 0.2230 Acc: 0.9386
# Val Loss: 0.3144 Acc: 0.8788
# Epoch 48/50
# Train Loss: 0.1982 Acc: 0.9561
# Val Loss: 0.3004 Acc: 0.8889
# Epoch 49/50
# Train Loss: 0.1934 Acc: 0.9561
# Val Loss: 0.3032 Acc: 0.8889
# Epoch 50/50
# Train Loss: 0.1815 Acc: 0.9649
# Val Loss: 0.2870 Acc: 0.8889
# Best Validation Accuracy: 0.9293
# Model saved to registery/landmark_lstm.pth
